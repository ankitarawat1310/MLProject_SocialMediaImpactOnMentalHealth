# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Step 1: Loading and understanding the dataset

# %%
#Load the dataset
df1 = pd.read_csv("smmh.csv")

# %%
# Make a working copy
df = df1.copy()

# %%
#Check structure
print(f"Number of rows: {df.shape[0]} and columns: {df.shape[1]}\n")
# Out:
# Number of rows: 481 and columns: 21

# %%
print(df.columns.tolist())
# Out:
# ['Timestamp', '1. What is your age?', '2. Gender', '3. Relationship Status', '4. Occupation Status', '5. What type of organizations are you affiliated with?', '6. Do you use social media?', '7. What social media platforms do you commonly use?', '8. What is the average time you spend on social media every day?', '9. How often do you find yourself using Social media without a specific purpose?', '10. How often do you get distracted by Social media when you are busy doing something?', "11. Do you feel restless if you haven't used Social media in a while?", '12. On a scale of 1 to 5, how easily distracted are you?', '13. On a scale of 1 to 5, how much are you bothered by worries?', '14. Do you find it difficult to concentrate on things?', '15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?', '16. Following the previous question, how do you feel about these comparisons, generally speaking?', '17. How often do you look to seek validation from features of social media?', '18. How often do you feel depressed or down?', '19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?', '20. On a scale of 1 to 5, how often do you face issues regarding sleep?']

# %%
display(df.head())
# Out:
#             Timestamp  1. What is your age? 2. Gender 3. Relationship Status  \
# 0  4/18/2022 19:18:47                  21.0      Male      In a relationship
# 1  4/18/2022 19:19:28                  21.0    Female                 Single
# 2  4/18/2022 19:25:59                  21.0    Female                 Single
# 3  4/18/2022 19:29:43                  21.0    Female                 Single
# 4  4/18/2022 19:33:31                  21.0    Female                 Single
#
#   4. Occupation Status 5. What type of organizations are you affiliated with?  \
# 0   University Student                                         University
# 1   University Student                                         University
# 2   University Student                                         University
# 3   University Student                                         University
# 4   University Student                                         University
#
#   6. Do you use social media?  \
# 0                         Yes
# 1                         Yes
# 2                         Yes
# 3                         Yes
# 4                         Yes
#
#   7. What social media platforms do you commonly use?  \
# 0  Facebook, Twitter, Instagram, YouTube, Discord...
# 1  Facebook, Twitter, Instagram, YouTube, Discord...
# 2            Facebook, Instagram, YouTube, Pinterest
# 3                                Facebook, Instagram
# 4                       Facebook, Instagram, YouTube
#
#   8. What is the average time you spend on social media every day?  \
# 0                              Between 2 and 3 hours
# 1                                  More than 5 hours
# 2                              Between 3 and 4 hours
# 3                                  More than 5 hours
# 4                              Between 2 and 3 hours
#
#    9. How often do you find yourself using Social media without a specific purpose?  \
# 0                                                  5
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  3
#
#    ...  11. Do you feel restless if you haven't used Social media in a while?  \
# 0  ...                                                  2
# 1  ...                                                  2
# 2  ...                                                  1
# 3  ...                                                  1
# 4  ...                                                  4
#
#    12. On a scale of 1 to 5, how easily distracted are you?  \
# 0                                                  5
# 1                                                  4
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    13. On a scale of 1 to 5, how much are you bothered by worries?  \
# 0                                                  2
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    14. Do you find it difficult to concentrate on things?  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  5
#
#    15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?  \
# 0                                                  2
# 1                                                  5
# 2                                                  3
# 3                                                  5
# 4                                                  3
#
#    16. Following the previous question, how do you feel about these comparisons, generally speaking?  \
# 0                                                  3
# 1                                                  1
# 2                                                  3
# 3                                                  1
# 4                                                  3
#
#    17. How often do you look to seek validation from features of social media?  \
# 0                                                  2
# 1                                                  1
# 2                                                  1
# 3                                                  2
# 4                                                  3
#
#    18. How often do you feel depressed or down?  \
# 0                                             5
# 1                                             5
# 2                                             4
# 3                                             4
# 4                                             4
#
#    19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?  \
# 0                                                  4
# 1                                                  4
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    20. On a scale of 1 to 5, how often do you face issues regarding sleep?
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  2
# 4                                                  1
#
# [5 rows x 21 columns]

# %% [markdown]
# Check for datatype and

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 21 columns):
#  #   Column                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                --------------  -----
#  0   Timestamp                                                                                                             481 non-null    object
#  1   1. What is your age?                                                                                                  481 non-null    float64
#  2   2. Gender                                                                                                             481 non-null    object
#  3   3. Relationship Status                                                                                                481 non-null    object
#  4   4. Occupation Status                                                                                                  481 non-null    object
#  5   5. What type of organizations are you affiliated with?                                                                451 non-null    object
#  6   6. Do you use social media?                                                                                           481 non-null    object
#  7   7. What social media platforms do you commonly use?                                                                   481 non-null    object
#  8   8. What is the average time you spend on social media every day?                                                      481 non-null    object
#  9   9. How often do you find yourself using Social media without a specific purpose?                                      481 non-null    int64
#  10  10. How often do you get distracted by Social media when you are busy doing something?                                481 non-null    int64
#  11  11. Do you feel restless if you haven't used Social media in a while?                                                 481 non-null    int64
#  12  12. On a scale of 1 to 5, how easily distracted are you?                                                              481 non-null    int64
#  13  13. On a scale of 1 to 5, how much are you bothered by worries?                                                       481 non-null    int64
#  14  14. Do you find it difficult to concentrate on things?                                                                481 non-null    int64
#  15  15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?  481 non-null    int64
#  16  16. Following the previous question, how do you feel about these comparisons, generally speaking?                     481 non-null    int64
#  17  17. How often do you look to seek validation from features of social media?                                           481 non-null    int64
#  18  18. How often do you feel depressed or down?                                                                          481 non-null    int64
#  19  19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?                            481 non-null    int64
#  20  20. On a scale of 1 to 5, how often do you face issues regarding sleep?                                               481 non-null    int64
# dtypes: float64(1), int64(12), object(8)
# memory usage: 79.0+ KB

# %% [markdown]
# Based on all these columns , I can say below variables as target variable and feature
#
# There are three type of columns(Classify the columns)
#
#     1. Feature variable (column number and a line to explain why)
#     2. Target variable
#     3. Timestamp  (0th columb)

# %%
#Classify categorical vs numerical
categorical_cols = df.select_dtypes(include='object')
numerical_cols = df.select_dtypes(include=np.number)
#target_cols = df.select_ ->all
#feature_cols

# %% [markdown]
# Data types tell you if variables are numerical, categorical, or dates.
# Helps you decide what kind of visualizations or transformations to apply.

# %% [markdown]
# Missing value analysis tells you which questions were skipped — important for cleaning.

# %% [markdown]
# **Investigation of categorical columns**

# %%
# Check unique values in categorical columns
for col in categorical_cols:
    print(df[col].value_counts())
# Out:
# Timestamp
# 5/11/2022 22:54:32     2
# 4/18/2022 19:18:47     1
# 5/11/2022 22:38:29     1
# 5/11/2022 22:34:14     1
# 5/11/2022 22:33:56     1
#                       ..
# 4/20/2022 0:07:24      1
# 4/20/2022 0:00:36      1
# 4/19/2022 23:53:34     1
# 4/19/2022 23:51:19     1
# 11/12/2022 13:16:50    1
# Name: count, Length: 480, dtype: int64
# 2. Gender
# Female                 263
# Male                   211
# Nonbinary                1
# Non-binary               1
# NB                       1
# unsure                   1
# Trans                    1
# Non binary               1
# There are others???      1
# Name: count, dtype: int64
# 3. Relationship Status
# Single               285
# Married              101
# In a relationship     88
# Divorced               7
# Name: count, dtype: int64
# 4. Occupation Status
# University Student    292
# Salaried Worker       132
# School Student         49
# Retired                 8
# Name: count, dtype: int64
# 5. What type of organizations are you affiliated with?
# University                        239
# Private                            60
# School                             44
# Company                            30
# University, Company                19
# University, Private                16
# School, University                  9
# Company, Private                    7
# Goverment                           6
# University, Company, Private        5
# School, University, Private         4
# University, N/A                     3
# University, Goverment               2
# School, Company                     2
# School, N/A                         2
# University, Company, Goverment      1
# School, Private                     1
# University, Goverment, Private      1
# Name: count, dtype: int64
# 6. Do you use social media?
# Yes    478
# No       3
# Name: count, dtype: int64
# 7. What social media platforms do you commonly use?
# Facebook, Instagram, YouTube                                                 35
# Facebook, YouTube                                                            30
# Facebook, Instagram, YouTube, Snapchat                                       28
# Facebook, Instagram, YouTube, Snapchat, Discord                              19
# Facebook, Instagram, YouTube, Discord                                        18
#                                                                              ..
# Facebook, Discord, Reddit                                                     1
# Twitter, Instagram, YouTube, Snapchat, Discord, Reddit, Pinterest, TikTok     1
# Reddit, Pinterest                                                             1
# Instagram, YouTube, Discord, Reddit, TikTok                                   1
# Instagram, YouTube, Snapchat, Discord, Reddit, Pinterest, TikTok              1
# Name: count, Length: 125, dtype: int64
# 8. What is the average time you spend on social media every day?
# More than 5 hours        116
# Between 2 and 3 hours    101
# Between 3 and 4 hours     93
# Between 1 and 2 hours     70
# Between 4 and 5 hours     67
# Less than an Hour         34
# Name: count, dtype: int64

# %% [markdown]
# It shows you only the columns that have missing values in your DataFrame df, along with the count of missing values in each.

# %% [markdown]
# **Based on some intution looking for correlation between taregt variable and feature variable**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Create age bins and labels
bins = list(range(10, int(df['1. What is your age?'].max()) + 10, 10))
labels = [f"{bins[i]}–{bins[i+1]-1}" for i in range(len(bins)-1)]
df['age_group'] = pd.cut(df['1. What is your age?'], bins=bins, labels=labels, right=False)

# Step 2: Define columns
q18 = '18. How often do you feel depressed or down?'
social_media_col = '8. What is the average time you spend on social media every day?'

# Step 3: Group by age group and social media time
grouped = df.groupby(['age_group', social_media_col])[q18].mean().unstack()

# Step 4: Prepare grouped bar chart (but do not show yet)
grouped.plot(kind='bar', figsize=(10, 6), colormap='Set2')
plt.title("Avg Depression Score (Q18) by Age Group & Social Media Usage")
plt.xlabel("Age Group")
plt.ylabel("Average Depression Score")
plt.xticks(rotation=45)
plt.legend(title="Social Media Time")
plt.grid(axis='y')
plt.tight_layout()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("smmh.csv")

# Define the columns
rel_col = '3. Relationship Status'
time_col = '8. What is the average time you spend on social media every day?'

# Create grouped count (how many people in each relationship status use social media X hours)
grouped = df.groupby([rel_col, time_col]).size().unstack(fill_value=0)

# Prepare grouped bar plot (but don’t show it yet)
grouped.plot(kind='bar', figsize=(10, 6), colormap='Set3')
plt.title("Social Media Usage by Relationship Status")
plt.xlabel("Relationship Status")
plt.ylabel("Number of Users")
plt.xticks(rotation=45)
plt.legend(title="Social Media Time")
plt.tight_layout()

# ⚠️ Run plt.show() when ready to view the plot

# %%
# Step 1: Create Age Group column
bins = [0, 18, 25, 35, 50, 100]
labels = ['<18', '18-25', '26-35', '36-50', '50+']
df['Age Group'] = pd.cut(df['1. What is your age?'], bins=bins, labels=labels)

# %%
# Step 2: Boxplot by Age Group
plt.figure(figsize=(8, 5))
sns.boxplot(x='Age Group', y='18. How often do you feel depressed or down?', data=df)
plt.title("Depression Score by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Depression Score (Q18)")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Younger age groups (18–25 and 26–35) tend to report higher depression scores, with some individuals reaching the max score of 5.
#
# Older age groups (36–60) seem to have lower depression scores on average and narrower spread (less variance).
#
# The 60+ group shows a wider range again, possibly due to smaller sample size or varying life situations.

# %%
# Clean gender column
df['2. Gender'] = df['2. Gender'].str.strip().str.lower()

gender_map = {
    'male': 'Male',
    'female': 'Female',
    'nonbinary': 'Non-binary',
    'nb': 'Non-binary',
    'trans': 'Trans',
    'transnonbinary': 'Trans',
    'others': 'Other',
    'other': 'Other',
    '???': 'Other',
    'unsure': 'Other'
}

df['Gender Cleaned'] = df['2. Gender'].map(gender_map).fillna('Other')

# %%
target = '18. How often do you feel depressed or down?'

col = '2. Gender'

grouped = df.groupby(col)[target].mean().reset_index().sort_values(by=target, ascending=False)

plt.figure(figsize=(8, 4))
plt.bar(grouped[col], grouped[target], color='orchid')
plt.title("Average Depression Score by Gender")
plt.xlabel("Gender")
plt.ylabel("Average Depression Score")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Participants identifying as Trans, Non-binary, or Other genders report higher median depression scores compared to Male and Female participants.
#
# This suggests that individuals outside the binary gender spectrum may be experiencing greater mental health challenges, highlighting the need for more inclusive and targeted support in mental health initiatives.

# %%
# --------- Plot 3: Depression vs Relationship Status ---------
plt.figure(figsize=(7, 5))
sns.boxplot(x='3. Relationship Status', y='18. How often do you feel depressed or down?', data=df)
plt.title("Depression Score by Relationship Status")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# Relationship status appears to influence depression levels.
#
# Individuals who are single or in a relationship show higher median depression scores.
#
# Married participants generally report lower depression scores, indicating potential emotional stability.
#
# Divorced participants also show a wide range in responses, with a slightly higher median than married ones.

# %%
col = '4. Occupation Status'

grouped = df.groupby(col)[target].mean().reset_index().sort_values(by=target, ascending=False)

plt.figure(figsize=(8, 4))
plt.bar(grouped[col], grouped[target], color='mediumseagreen')
plt.title("Average Depression Score by Occupation")
plt.xlabel("Occupation Status")
plt.ylabel("Average Depression Score")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Occupation status appears to be related to mental health.
#
# University students might be more prone to feeling depressed, possibly due to academic pressure, transition stress, or social factors.
#
# This makes Occupation Status a valuable feature for modeling depression risk.

# %%
# Define the column
org_col = '5. What type of organizations are you affiliated with?'

# Define a function to classify into 4 simplified groups
def simplify_org_type(value):
    if pd.isnull(value):
        return 'Unknown'
    orgs = value.lower()
    if ',' in orgs:
        return 'Multiple Affiliations'
    elif 'school' in orgs:
        return 'Only School'
    elif 'university' in orgs:
        return 'Only University'
    elif 'private' in orgs:
        return 'Only Private'
    else:
        return 'Other'

# Apply to create a new column
df['Org Group'] = df[org_col].apply(simplify_org_type)

# %%
# --------- Plot 5: Depression vs Organization Type ---------
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.boxplot(x='Org Group', y='18. How often do you feel depressed or down?', data=df)
plt.title("Depression Score by Simplified Organization Affiliation")
plt.xlabel("Organization Group")
plt.ylabel("Depression Score (Q18)")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
#  Individuals affiliated with multiple organizations (e.g., university, private, school) show the highest median depression scores, indicating that juggling multiple roles may increase stress and emotional burden.
#
# 📊 Only School group shows the lowest depression scores, possibly due to lower exposure to external responsibilities.
#
# 🧑‍🎓 Only University group also shows a relatively higher median depression score—which aligns with prior findings that university students often experience academic and social pressures.
#
# 🏢 Only Private and Unknown/Other groups lie in the middle, suggesting mixed influence or variability in personal and work environments.

# %%
# --------- Plot 6: Depression vs Use of Social Media ---------
plt.figure(figsize=(6, 4))
sns.boxplot(x='6. Do you use social media?', y='18. How often do you feel depressed or down?', data=df)
plt.title("Depression vs Social Media Usage")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 4))

# Single clean color
sns.boxplot(
    x='6. Do you use social media?', 
    y='18. How often do you feel depressed or down?', 
    data=df,
    color='steelblue'
)

# Proper, non-bold title and labels
plt.title("Depression vs Social Media Usage", fontsize=14)
plt.xlabel("Social Media Usage", fontsize=12)
plt.ylabel("Depression Score", fontsize=12)

# Light Grid
plt.grid(True, linestyle='--', alpha=0.5)

# Tight Layout
plt.tight_layout()

# Save high-quality figure
plt.savefig('Depression_vs_SocialMedia_Clean.png', dpi=300)

plt.show()

# %%
# 📦 Imports
import pandas as pd
import matplotlib.pyplot as plt

# 📂 Load your dataset
df = pd.read_csv('smmh.csv')

# 📌 Count Depression Scores (1–5)
score_counts = df['18. How often do you feel depressed or down?'].value_counts().sort_index()

# 📈 Create the plot
plt.figure(figsize=(7, 5))
score_counts.plot(
    kind='bar',
    color='steelblue',
    edgecolor='black',
    width=0.6
)
plt.title('Distribution of Depression Scores (1 to 5)', fontsize=14)
plt.xlabel('Depression Score', fontsize=12)
plt.ylabel('Number of Respondents', fontsize=12)
plt.xticks(rotation=0, fontsize=11)
plt.yticks(fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(['Respondents'], loc='upper right', fontsize=10)

# 📥 Save the plot as an image file
plt.savefig('Depression_Score_Distribution.png', dpi=300)
plt.tight_layout()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('smmh.csv')

# Focus on time spent
time_spent = df['8. What is the average time you spend on social media every day?']

# Set a clean style
sns.set_theme(style="whitegrid")

# Correct category order
order = [
    'Less than an Hour',
    'Between 1 and 2 hours',
    'Between 2 and 3 hours',
    'Between 3 and 4 hours',
    'Between 4 and 5 hours',
    'More than 5 hours'
]

# Create the plot
plt.figure(figsize=(9, 6))
ax = sns.countplot(
    y=time_spent,
    order=order,
    palette='Blues_r',
    edgecolor='black'
)

# Titles and labels
plt.title('Distribution of Daily Social Media Usage Time', fontsize=16)
plt.xlabel('Number of Respondents', fontsize=13)
plt.ylabel('Daily Time Spent on Social Media', fontsize=13)

# Ticks
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)

# Grid
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Legend in TOP RIGHT
plt.legend(['Respondents'], loc='upper right', fontsize=11, frameon=False)

# Layout
plt.tight_layout()

# Save figure
plt.savefig('Social_Media_Time_Horizontal.png', dpi=300)

# Show
plt.show()
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_20096\870443482.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %%
# --------- Plot 7: Depression vs Platforms Used ---------
# Count number of platforms per user
df['platform_count'] = df['7. What social media platforms do you commonly use?'].apply(lambda x: len(str(x).split(',')))
sns.boxplot(x='platform_count', y='18. How often do you feel depressed or down?', data=df)
plt.title("Depression Score by Number of Platforms Used")
plt.xlabel("Number of Platforms Used")
plt.ylabel("Depression Score (Q18)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Key Insight – Depression vs Number of Platforms Used:
# Upward Trend: As the number of platforms used increases, the median depression score also tends to rise slightly.
#
# Wider Spread: Users who use many platforms (6–9) show a broader range of depression scores, with some reaching the maximum (5). This could indicate more emotional variability.
#
# Lower Depression in Low Users: Those using 1–2 platforms tend to have lower depression scores overall.

# %%
# --------- Plot 8: Depression vs Time Spent on Social Media ---------
plt.figure(figsize=(9, 5))
sns.boxplot(x='8. What is the average time you spend on social media every day?', y='18. How often do you feel depressed or down?', data=df)
plt.title("Depression Score by Time Spent on Social Media")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('smmh.csv')

# Set the style
sns.set_theme(style="whitegrid")

# Plot
plt.figure(figsize=(10, 6))
sns.boxplot(
    x='8. What is the average time you spend on social media every day?',
    y='18. How often do you feel depressed or down?',
    data=df,
    palette='Blues'
)

# Titles and labels
plt.title('Depression Score by Time Spent on Social Media', fontsize=16)
plt.xlabel('Daily Time Spent on Social Media', fontsize=13)
plt.ylabel('Depression Score', fontsize=13)

# Ticks
plt.xticks(rotation=45, ha='right', fontsize=11)
plt.yticks(fontsize=11)

# Add light grid
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Layout adjustment
plt.tight_layout()

# Save the plot
plt.savefig('Depression_vs_SocialMedia_Time_Boxplot.png', dpi=300)

# Show
plt.show()
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_20096\3888919193.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('smmh.csv')

# Set clean style
sns.set_theme(style="whitegrid")

# Correct X-axis order without wrapping
order = [
    'Less than an Hour',
    'Between 1 and 2 hours',
    'Between 2 and 3 hours',
    'Between 3 and 4 hours',
    'Between 4 and 5 hours',
    'More than 5 hours'
]

# Plot Violin Plot
plt.figure(figsize=(10, 6))
sns.violinplot(
    x='8. What is the average time you spend on social media every day?',
    y='18. How often do you feel depressed or down?',
    data=df,
    order=order,
    palette='Blues'
)

# Titles and Labels
plt.title('Distribution of Depression Scores by Social Media Usage Time', fontsize=16)
plt.xlabel('Daily Time Spent on Social Media', fontsize=13, labelpad=20)
plt.ylabel('Depression Score', fontsize=13)

# Rotate X-axis labels nicely
plt.xticks(rotation=30, ha='right', fontsize=11)
plt.yticks(fontsize=11)

# Grid for Y-axis only
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Layout
plt.tight_layout()

# Save
plt.savefig('Depression_Score_Violin_Plot.png', dpi=300)
plt.show()
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_20096\210183039.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %% [markdown]
# “There appears to be a positive association between the amount of time spent on social media and reported depression scores. Participants who spend more than 5 hours daily on social media report the highest median depression levels, while those who spend less than an hour report the lowest. This suggests time spent on social media could be a significant predictor of mental health decline.”

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your data
df = pd.read_csv('smmh.csv')

# Define the correct order for time groups
time_order = [
    'Less than an Hour',
    'Between 1 and 2 hours',
    'Between 2 and 3 hours',
    'Between 3 and 4 hours',
    'Between 4 and 5 hours',
    'More than 5 hours'
]

# Make the time group categorical and ordered
df['Time Group'] = pd.Categorical(
    df['8. What is the average time you spend on social media every day?'],
    categories=time_order,
    ordered=True
)

# Setup FacetGrid
sns.set(style="whitegrid", font_scale=1.1)
g = sns.FacetGrid(
    df,
    col="Time Group",
    col_wrap=3,
    height=4,
    sharey=True
)

# Plot percentage-based histograms
g.map_dataframe(
    sns.histplot,
    x="18. How often do you feel depressed or down?",
    bins=5,
    discrete=True,
    stat="percent",  # 🎯 This shows % instead of count
    color="#6B6226"
)

g.set_titles(col_template="{col_name}")
g.set_axis_labels("Depression Score", "Percentage (%)")

# Style tweaks
for ax in g.axes.flat:
    ax.set_facecolor("#F5F3E5")
    ax.set_xticks([1, 2, 3, 4, 5])

plt.subplots_adjust(top=0.88)
g.fig.suptitle("Percentage Distribution of Depression Scores by Time Spent on Social Media", fontsize=16, weight='bold', color="#6B6226")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select mental health-related columns
mental_health_cols = [
    '13. On a scale of 1 to 5, how much are you bothered by worries?',
    '14. Do you find it difficult to concentrate on things?',
    '18. How often do you feel depressed or down?',
    '19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?',
    '20. On a scale of 1 to 5, how often do you face issues regarding sleep?'
]

# Compute correlation matrix
corr_matrix = df[mental_health_cols].corr()

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Between Mental Health Questions')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig('Feature_Correlation_Matrix.png', dpi=300)
plt.show()
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_20096\615019342.py:22: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select mental health-related columns
mental_health_cols = [
    '13. On a scale of 1 to 5, how much are you bothered by worries?',
    '14. Do you find it difficult to concentrate on things?',
    '18. How often do you feel depressed or down?',
    '19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?',
    '20. On a scale of 1 to 5, how often do you face issues regarding sleep?'
]

# Compute correlation matrix
corr_matrix = df[mental_health_cols].corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))  # Slightly bigger height
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

# Titles and labels
plt.title('Correlation Between Mental Health Questions', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)  # Slightly rotate for cleaner text
plt.yticks(rotation=0, fontsize=10)

# Tight layout + save properly
plt.tight_layout()
plt.savefig('Feature_Correlation_Matrix.png', dpi=300, bbox_inches='tight')  # 🛠 FIXED HERE
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('smmh.csv')

# Select numeric/ordinal columns (corrected names, double quotes)
numeric_cols = [
    '1. What is your age?',
    '9. How often do you find yourself using Social media without a specific purpose?',
    '10. How often do you get distracted by Social media when you are busy doing something?',
    "11. Do you feel restless if you haven't used Social media in a while?",
    '12. On a scale of 1 to 5, how easily distracted are you?',
    '13. On a scale of 1 to 5, how much are you bothered by worries?',
    '14. Do you find it difficult to concentrate on things?',
    "15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?",
    '16. Following the previous question, how do you feel about these comparisons, generally speaking?',
    '17. How often do you look to seek validation from features of social media?',
    '18. How often do you feel depressed or down?',
    '19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?',
    '20. On a scale of 1 to 5, how often do you face issues regarding sleep?'
]

# Filter numeric columns
Num_df = df[numeric_cols]

# Compute correlation matrix
correlation_matrix = Num_df.corr()

# (Optional) Display correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                                                     1. What is your age?  \
# 1. What is your age?                                            1.000000
# 9. How often do you find yourself using Social ...             -0.225131
# 10. How often do you get distracted by Social m...             -0.232202
# 11. Do you feel restless if you haven't used So...             -0.125806
# 12. On a scale of 1 to 5, how easily distracted...             -0.224487
# 13. On a scale of 1 to 5, how much are you both...             -0.288539
# 14. Do you find it difficult to concentrate on ...             -0.264555
# 15. On a scale of 1-5, how often do you compare...             -0.092315
# 16. Following the previous question, how do you...              0.017910
# 17. How often do you look to seek validation fr...             -0.038936
# 18. How often do you feel depressed or down?                   -0.303582
# 19. On a scale of 1 to 5, how frequently does y...             -0.241239
# 20. On a scale of 1 to 5, how often do you face...             -0.161129
#
#                                                     9. How often do you find yourself using Social media without a specific purpose?  \
# 1. What is your age?                                                                        -0.225131
# 9. How often do you find yourself using Social ...                                           1.000000
# 10. How often do you get distracted by Social m...                                           0.463353
# 11. Do you feel restless if you haven't used So...                                           0.359031
# 12. On a scale of 1 to 5, how easily distracted...                                           0.365491
# 13. On a scale of 1 to 5, how much are you both...                                           0.252082
# 14. Do you find it difficult to concentrate on ...                                           0.288829
# 15. On a scale of 1-5, how often do you compare...                                           0.148203
# 16. Following the previous question, how do you...                                           0.087645
# 17. How often do you look to seek validation fr...                                           0.144519
# 18. How often do you feel depressed or down?                                                 0.315478
# 19. On a scale of 1 to 5, how frequently does y...                                           0.359379
# 20. On a scale of 1 to 5, how often do you face...                                           0.260496
#
#                                                     10. How often do you get distracted by Social media when you are busy doing something?  \
# 1. What is your age?                                                                        -0.232202
# 9. How often do you find yourself using Social ...                                           0.463353
# 10. How often do you get distracted by Social m...                                           1.000000
# 11. Do you feel restless if you haven't used So...                                           0.513354
# 12. On a scale of 1 to 5, how easily distracted...                                           0.607419
# 13. On a scale of 1 to 5, how much are you both...                                           0.343307
# 14. Do you find it difficult to concentrate on ...                                           0.527745
# 15. On a scale of 1-5, how often do you compare...                                           0.288504
# 16. Following the previous question, how do you...                                           0.078065
# 17. How often do you look to seek validation fr...                                           0.270144
# 18. How often do you feel depressed or down?                                                 0.379444
# 19. On a scale of 1 to 5, how frequently does y...                                           0.389132
# 20. On a scale of 1 to 5, how often do you face...                                           0.255362
#
#                                                     11. Do you feel restless if you haven't used Social media in a while?  \
# 1. What is your age?                                                                        -0.125806
# 9. How often do you find yourself using Social ...                                           0.359031
# 10. How often do you get distracted by Social m...                                           0.513354
# 11. Do you feel restless if you haven't used So...                                           1.000000
# 12. On a scale of 1 to 5, how easily distracted...                                           0.514801
# 13. On a scale of 1 to 5, how much are you both...                                           0.347036
# 14. Do you find it difficult to concentrate on ...                                           0.469440
# 15. On a scale of 1-5, how often do you compare...                                           0.320973
# 16. Following the previous question, how do you...                                           0.134191
# 17. How often do you look to seek validation fr...                                           0.245925
# 18. How often do you feel depressed or down?                                                 0.328969
# 19. On a scale of 1 to 5, how frequently does y...                                           0.384770
# 20. On a scale of 1 to 5, how often do you face...                                           0.166601
#
#                                                     12. On a scale of 1 to 5, how easily distracted are you?  \
# 1. What is your age?                                                                        -0.224487
# 9. How often do you find yourself using Social ...                                           0.365491
# 10. How often do you get distracted by Social m...                                           0.607419
# 11. Do you feel restless if you haven't used So...                                           0.514801
# 12. On a scale of 1 to 5, how easily distracted...                                           1.000000
# 13. On a scale of 1 to 5, how much are you both...                                           0.462673
# 14. Do you find it difficult to concentrate on ...                                           0.662768
# 15. On a scale of 1-5, how often do you compare...                                           0.286120
# 16. Following the previous question, how do you...                                           0.014630
# 17. How often do you look to seek validation fr...                                           0.172585
# 18. How often do you feel depressed or down?                                                 0.407667
# 19. On a scale of 1 to 5, how frequently does y...                                           0.479993
# 20. On a scale of 1 to 5, how often do you face...                                           0.291147
#
#                                                     13. On a scale of 1 to 5, how much are you bothered by worries?  \
# 1. What is your age?                                                                        -0.288539
# 9. How often do you find yourself using Social ...                                           0.252082
# 10. How often do you get distracted by Social m...                                           0.343307
# 11. Do you feel restless if you haven't used So...                                           0.347036
# 12. On a scale of 1 to 5, how easily distracted...                                           0.462673
# 13. On a scale of 1 to 5, how much are you both...                                           1.000000
# 14. Do you find it difficult to concentrate on ...                                           0.545904
# 15. On a scale of 1-5, how often do you compare...                                           0.414301
# 16. Following the previous question, how do you...                                           0.020589
# 17. How often do you look to seek validation fr...                                           0.208847
# 18. How often do you feel depressed or down?                                                 0.588757
# 19. On a scale of 1 to 5, how frequently does y...                                           0.430348
# 20. On a scale of 1 to 5, how often do you face...                                           0.327367
#
#                                                     14. Do you find it difficult to concentrate on things?  \
# 1. What is your age?                                                                        -0.264555
# 9. How often do you find yourself using Social ...                                           0.288829
# 10. How often do you get distracted by Social m...                                           0.527745
# 11. Do you feel restless if you haven't used So...                                           0.469440
# 12. On a scale of 1 to 5, how easily distracted...                                           0.662768
# 13. On a scale of 1 to 5, how much are you both...                                           0.545904
# 14. Do you find it difficult to concentrate on ...                                           1.000000
# 15. On a scale of 1-5, how often do you compare...                                           0.371156
# 16. Following the previous question, how do you...                                           0.060742
# 17. How often do you look to seek validation fr...                                           0.242035
# 18. How often do you feel depressed or down?                                                 0.509794
# 19. On a scale of 1 to 5, how frequently does y...                                           0.503196
# 20. On a scale of 1 to 5, how often do you face...                                           0.354676
#
#                                                     15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?  \
# 1. What is your age?                                                                        -0.092315
# 9. How often do you find yourself using Social ...                                           0.148203
# 10. How often do you get distracted by Social m...                                           0.288504
# 11. Do you feel restless if you haven't used So...                                           0.320973
# 12. On a scale of 1 to 5, how easily distracted...                                           0.286120
# 13. On a scale of 1 to 5, how much are you both...                                           0.414301
# 14. Do you find it difficult to concentrate on ...                                           0.371156
# 15. On a scale of 1-5, how often do you compare...                                           1.000000
# 16. Following the previous question, how do you...                                          -0.011468
# 17. How often do you look to seek validation fr...                                           0.417328
# 18. How often do you feel depressed or down?                                                 0.417801
# 19. On a scale of 1 to 5, how frequently does y...                                           0.374242
# 20. On a scale of 1 to 5, how often do you face...                                           0.193716
#
#                                                     16. Following the previous question, how do you feel about these comparisons, generally speaking?  \
# 1. What is your age?                                                                         0.017910
# 9. How often do you find yourself using Social ...                                           0.087645
# 10. How often do you get distracted by Social m...                                           0.078065
# 11. Do you feel restless if you haven't used So...                                           0.134191
# 12. On a scale of 1 to 5, how easily distracted...                                           0.014630
# 13. On a scale of 1 to 5, how much are you both...                                           0.020589
# 14. Do you find it difficult to concentrate on ...                                           0.060742
# 15. On a scale of 1-5, how often do you compare...                                          -0.011468
# 16. Following the previous question, how do you...                                           1.000000
# 17. How often do you look to seek validation fr...                                           0.153574
# 18. How often do you feel depressed or down?                                                 0.035470
# 19. On a scale of 1 to 5, how frequently does y...                                           0.046153
# 20. On a scale of 1 to 5, how often do you face...                                           0.068510
#
#                                                     17. How often do you look to seek validation from features of social media?  \
# 1. What is your age?                                                                        -0.038936
# 9. How often do you find yourself using Social ...                                           0.144519
# 10. How often do you get distracted by Social m...                                           0.270144
# 11. Do you feel restless if you haven't used So...                                           0.245925
# 12. On a scale of 1 to 5, how easily distracted...                                           0.172585
# 13. On a scale of 1 to 5, how much are you both...                                           0.208847
# 14. Do you find it difficult to concentrate on ...                                           0.242035
# 15. On a scale of 1-5, how often do you compare...                                           0.417328
# 16. Following the previous question, how do you...                                           0.153574
# 17. How often do you look to seek validation fr...                                           1.000000
# 18. How often do you feel depressed or down?                                                 0.272125
# 19. On a scale of 1 to 5, how frequently does y...                                           0.278575
# 20. On a scale of 1 to 5, how often do you face...                                           0.128898
#
#                                                     18. How often do you feel depressed or down?  \
# 1. What is your age?                                                                   -0.303582
# 9. How often do you find yourself using Social ...                                      0.315478
# 10. How often do you get distracted by Social m...                                      0.379444
# 11. Do you feel restless if you haven't used So...                                      0.328969
# 12. On a scale of 1 to 5, how easily distracted...                                      0.407667
# 13. On a scale of 1 to 5, how much are you both...                                      0.588757
# 14. Do you find it difficult to concentrate on ...                                      0.509794
# 15. On a scale of 1-5, how often do you compare...                                      0.417801
# 16. Following the previous question, how do you...                                      0.035470
# 17. How often do you look to seek validation fr...                                      0.272125
# 18. How often do you feel depressed or down?                                            1.000000
# 19. On a scale of 1 to 5, how frequently does y...                                      0.494976
# 20. On a scale of 1 to 5, how often do you face...                                      0.374726
#
#                                                     19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?  \
# 1. What is your age?                                                                        -0.241239
# 9. How often do you find yourself using Social ...                                           0.359379
# 10. How often do you get distracted by Social m...                                           0.389132
# 11. Do you feel restless if you haven't used So...                                           0.384770
# 12. On a scale of 1 to 5, how easily distracted...                                           0.479993
# 13. On a scale of 1 to 5, how much are you both...                                           0.430348
# 14. Do you find it difficult to concentrate on ...                                           0.503196
# 15. On a scale of 1-5, how often do you compare...                                           0.374242
# 16. Following the previous question, how do you...                                           0.046153
# 17. How often do you look to seek validation fr...                                           0.278575
# 18. How often do you feel depressed or down?                                                 0.494976
# 19. On a scale of 1 to 5, how frequently does y...                                           1.000000
# 20. On a scale of 1 to 5, how often do you face...                                           0.319247
#
#                                                     20. On a scale of 1 to 5, how often do you face issues regarding sleep?
# 1. What is your age?                                                                        -0.161129
# 9. How often do you find yourself using Social ...                                           0.260496
# 10. How often do you get distracted by Social m...                                           0.255362
# 11. Do you feel restless if you haven't used So...                                           0.166601
# 12. On a scale of 1 to 5, how easily distracted...                                           0.291147
# 13. On a scale of 1 to 5, how much are you both...                                           0.327367
# 14. Do you find it difficult to concentrate on ...                                           0.354676
# 15. On a scale of 1-5, how often do you compare...                                           0.193716
# 16. Following the previous question, how do you...                                           0.068510
# 17. How often do you look to seek validation fr...                                           0.128898
# 18. How often do you feel depressed or down?                                                 0.374726
# 19. On a scale of 1 to 5, how frequently does y...                                           0.319247
# 20. On a scale of 1 to 5, how often do you face...                                           1.000000

# %%
# Set the style
sns.set_theme(style="whitegrid")

# Plot heatmap
plt.figure(figsize=(14, 12))
sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5,
    cbar_kws={"shrink": 0.75}
)

# Titles and labels
plt.title("Feature Correlation Matrix", fontsize=16)
plt.xticks(rotation=90, fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.tight_layout()

# Save the figure
plt.savefig('Feature_Correlation_Matrix_SplitCells.png', dpi=300)

# Show the plot
plt.show()

# %% [markdown]
# Correlation matrix shows how well it connects with related symptoms (like worry, concentration, etc.).
#
# You can explain in your report: “Q18 was chosen as the target because it shows moderate to strong correlations with other mental health indicators.”

# %% [markdown]
# Variable Pair | Correlation | Observation
# Q13 & Q18 (Worry & Depression) | 0.59 | Strongest correlation — makes sense logically.
# Q14 & Q18 (Concentration & Depression) | 0.51 | Also quite strong.
# Q19 & Q18 (Interest fluctuation & Depression) | 0.49 | Moderate.
# Q20 & Q18 (Sleep issues & Depression) | 0.37 | Weaker than others.

# %% [markdown]
# Q18. How often do you feel depressed or down? is well correlated with other key mental health indicators.
#
# It is a solid choice for your target variable

# %% [markdown]
# You can visually show that depression is not isolated, but connected to other cognitive or emotional challenges.

# %% [markdown]
# Based on the correlation matrix, we observe that depression (Q18) is positively correlated with related symptoms such as worry (Q13), concentration issues (Q14), and interest fluctuation (Q19). This confirms that Q18 is an appropriate target variable for further analysis and modeling, as it reflects a central aspect of mental health connected to other psychological indicators.

# %% [markdown]
# **Why Analyze Behavioral Social Media Features Now?**

# %% [markdown]
# These questions capture emotional + cognitive effects of social media. They directly relate to depression and:
#
# help find deeper psychological patterns
#
# could become the most important predictors in your model
#
# support stronger research findings and insights

# %%
# Define the list of behavioral features
behavior_features = [
    '9. How often do you find yourself using Social media without a specific purpose?',
    '10. How often do you get distracted by Social media when you are busy doing something?',
    '11. Do you feel restless if you haven\'t used Social media in a while?',
    '15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?',
    '17. How often do you look to seek validation from features of social media?'
]
# Bar plot of average depression score per social feature level
for feature in behavior_features:
    plt.figure(figsize=(10, 5))
    avg_df = df.groupby(feature)[target].mean().reset_index()
    sns.barplot(x=feature, y=target, data=avg_df, palette='crest')
    plt.title(f"Average Depression Score vs {feature}")
    plt.xlabel(feature)
    plt.ylabel("Average Depression Score (Q18)")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.grid(axis='y')
    plt.show()

# %% [markdown]
# missing rows needs to be hnadled
# Dependencies between mental health
